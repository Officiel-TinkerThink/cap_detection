# %%
import numpy

# %%
import os
from pathlib import Path
import glob

# %%
import yaml

with open('../config/settings.yaml', 'r') as f:
    config = yaml.safe_load(f)

print(config)
# Out:
# {'train': {'model': 'yolo11n.pt', 'data': 'configs/data.yaml', 'epochs': 100, 'batch': 16, 'imgsz': 320, 'lr0': 0.001, 'optimizer': 'AdamW'}, 'aug': {'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 10.0, 'translate': 0.1, 'scale': 0.5, 'shear': 2.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.1}, 'infer': {'model_path': 'runs/detect/train2/weights/best.pt', 'conf': 0.25, 'iou': 0.45, 'output_dir': 'inference_results', 'class_names': ['light_blue', 'dark_blue', 'others']}}

# %%
data_path = Path(os.getcwd()).parent / 'sample'
data_path
# Out:
# WindowsPath('d:/WORK/learn/cap_detection/sample')

# %%
image_files = list(data_path.glob('*.jpg'))

# %%
label_files = [
            Path(f).with_name(f.name.replace('.jpg', '.txt'))
            for f in image_files
        ]

# %%
label_files
# Out:
# [WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b2_1.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b2_15.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b2_3.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b3_2.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b3_3.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b3_4.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b4_1.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b4_2.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b4_3.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b5_2.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b5_3.txt'),
#  WindowsPath('d:/WORK/learn/cap_detection/sample/raw-250110_dc_s001_b5_5.txt')]
